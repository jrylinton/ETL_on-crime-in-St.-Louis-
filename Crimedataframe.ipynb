# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
jan_csv= "resources/January2019.CSV"
feb_csv="resources/February2019.CSV"
march_csv="resources/March2019.CSV"
april_csv="resources/April2019.CSV"
may_csv="resources/May2019.CSV"
june_csv="resources/June2019.CSV"
july_csv="resources/July2019.CSV"
august_csv="resources/August2019.CSV"
september_csv="resources/September2019.CSV"
october_csv="resources/October2019.CSV"
november_csv="resources/November2019.CSV"

december_excel="resources/December2019 2.xlsm"

jan_df=pd.read_csv(jan_csv)

# %%
feb_df=pd.read_csv(feb_csv)

# %%
march_df=pd.read_csv(march_csv)

# %%
april_df=pd.read_csv(april_csv)

# %%
may_df=pd.read_csv(may_csv)

# %%
june_df=pd.read_csv(june_csv)

# %%
july_df=pd.read_csv(july_csv)

# %%
august_df=pd.read_csv(august_csv)

# %%
september_df=pd.read_csv(september_csv)

# %%
october_df=pd.read_csv(october_csv)

# %%
november_df=pd.read_csv(november_csv)

# %%
december_df=pd.read_excel(december_excel)
december_df.head()
# Out:
#    Complaint CodedMonth           DateOccur FlagCrime FlagUnfounded  \
# 0  20-000870    2019-12 2013-12-01 12:00:00         Y
# 1  19-059995    2019-12 2019-12-01 00:01:00         Y
# 2  19-061685    2019-12 2019-12-01 00:05:00         Y
# 3  19-060008    2019-12 2019-12-01 00:20:00         Y
# 4  19-059992    2019-12 2019-12-01 00:25:00         Y
#
#   FlagAdministrative  Count FlagCleanup   Crime  District  \
# 0                         1              115400         6
# 1                         1              241100         1
# 2                         1               69702         2
# 3                         1              142320         3
# 4                         1              241100         4
#
#                                    Description ILEADSAddress ILEADSStreet  \
# 0         STLG BY DECEIT/IDENTITY THEFT REPORT          1260   GIMBLIN ST
# 1    DISORDERLY CONDUCT-PEACE DSTRB/INDIVIDUAL           506  SCHIRMER ST
# ...

# %%
dataframes=[jan_df,feb_df,march_df,april_df,may_df,june_df,july_df,
           august_df,september_df,october_df,november_df,december_df]
crime_df=pd.concat(dataframes)

# %%
crime_df.head()
# Out:
#    Complaint CodedMonth         DateOccur FlagCrime FlagUnfounded  \
# 0  19-004506    2019-01  01/01/2008 08:00         Y
# 1  19-002822    2019-01  01/01/2018 00:01         Y
# 2  19-003393    2019-01  01/01/2019 00:01         Y
# 3  19-000005    2019-01  01/01/2019 00:01         Y
# 4  19-000062    2019-01  01/01/2019 00:01         Y
#
#   FlagAdministrative  Count FlagCleanup   Crime  District  \
# 0                         1              115400         3
# 1                         1               43025         5
# 2                         1               69602         1
# 3                         1               41021         4
# 4                         1              152200         2
#
#                                     Description ILEADSAddress    ILEADSStreet  \
# 0          STLG BY DECEIT/IDENTITY THEFT REPORT          2806      WYOMING ST
# 1       ASSLT-AGGRAV-OTH-WPN-2ND-CHILD-DOMESTIC          5082     CABANNE AVE
# ...

# %%
cleandf=crime_df[["DateOccur","Description"]]
cleandf.head()
# Out:
#           DateOccur                                   Description
# 0  01/01/2008 08:00          STLG BY DECEIT/IDENTITY THEFT REPORT
# 1  01/01/2018 00:01       ASSLT-AGGRAV-OTH-WPN-2ND-CHILD-DOMESTIC
# 2  01/01/2019 00:01              LARCENY-ALL OTHER $500 - $24,999
# 3  01/01/2019 00:01  AGG.ASSAULT-FIREARM/CITIZEN CHILD 1ST DEGREE
# 4  01/01/2019 00:01          WEAPONS-CITY VIOL/DISCHRGING IN CITY

# %%
cleandf.rename(columns= {"DateOccur":"Date"},inplace=True)

# %%
cleandf.rename(columns= {"Description":"Crime"},inplace=True)

# %%
cleandf.head()
# Out:
#                Date                                         Crime
# 0  01/01/2008 08:00          STLG BY DECEIT/IDENTITY THEFT REPORT
# 1  01/01/2018 00:01       ASSLT-AGGRAV-OTH-WPN-2ND-CHILD-DOMESTIC
# 2  01/01/2019 00:01              LARCENY-ALL OTHER $500 - $24,999
# 3  01/01/2019 00:01  AGG.ASSAULT-FIREARM/CITIZEN CHILD 1ST DEGREE
# 4  01/01/2019 00:01          WEAPONS-CITY VIOL/DISCHRGING IN CITY

# %%
export_csv=cleandf.to_csv("resources/crimedatacombined")
